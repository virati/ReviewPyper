# %% [markdown]
# # Note
# - This is an optional notebook.
# - Warning: this may miss PDFs.
# - You can simply download all your desired PDFs into a single directory and use that directory for Notebook 03.

# %% [markdown]
# 1 - Download PDFs

# %%
# Path to mast_list.csv
csv_path = "/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/TMS_studies_influencing_memory/metadata/Updated_TMS_studies_influencing_memory.csv"

# Your email
email = "choward12@bwh.harvard.edu"

# %%
from calvin_utils.gpt_sys_review.pdf_utils import BulkPDFDownloaderV2
bulk_downloader = BulkPDFDownloaderV2(csv_path=csv_path, email=email)
bulk_downloader.run()

# %% [markdown]
# 2 - Postprocessing

# %%
csv_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/TMS_studies_influencing_memory/metadata/Updated_TMS_studies_influencing_memory.csv'

# %%
from calvin_utils.gpt_sys_review.pdf_utils import PdfPostProcess
post_processor = PdfPostProcess(master_list_path=csv_path, pdf_dir='PDFs', PMID_column='PMID', pdf_name_column='PMID')
post_processor.run()
# Out:
# ...
# First pass processing PDF files:  50%|█████     | 10/20 [00:00<00:00, 166440.63it/s]
# Updated master list saved to:  /Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/TMS_studies_influencing_memory/metadata/Updated_TMS_studies_influencing_memory.csv
# Failed to download:  24  of  124
# Failed to download these PMIDs:  ['33226801' '38709534' '30347013' '16084813' '14992978' '16809569'
#  '28045857' '20351570' '20854181' '15936729' '27299900' '16242826'
#  '14960293' '20407301' '31913967' '21524336' '11297719' '17478080'
#  '30077213' '22653158' '23076723' '27631152' '11731727' '36186505']
# Failed to rename these PDFs:  ['16339086.pdf', '31568683.pdf', '15760635.pdf', '10356626.pdf', '31300260.pdf', '24684933.pdf', '31815705.pdf', '30795490.pdf', '28068640.pdf', '20663568.pdf']

# %% [markdown]
# Your PDFs have been downloaded.
#
# Please check the master_list_pdfs.csv file to review and see if any PDFs failed to download. You will download those manually.
#
# - Enjoy. If this has been helpful, please consider adding Calvin Howard as a collaborator.
# - e: choward12@bwh.harvard.edu
